# %% [markdown]
# <a href="https://colab.research.google.com/github/MariamAmmar/6644_Final_Project/blob/main/Texas_projectgroup39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url1 = '/content/sample_data/price_fact.csv'
price_data = pd.read_csv(url1)
url2 = '/content/sample_data/site_dim.csv'
site_data = pd.read_csv(url2)

# %%
#rename column site_number to site_id

site_data.rename(columns={'site_number': 'site_id'}, inplace=True)

# %%
#Merge price_data and site_data based on site_number column

merged_data = pd.merge(price_data, site_data, on='site_id')

# %%
unique_sites_per_state = (
    merged_data.groupby('site_state_desc')['site_id']
    .nunique()
    .reset_index(name='unique_site_count')
)

print(unique_sites_per_state)
# Out:
#    site_state_desc  unique_site_count
# 0          Alabama                145
# 1           Alaska                 24
# 2          Arizona                555
# 3         Arkansas                 12
# 4       California                165
# 5         Colorado                176
# 6          Florida                638
# 7          Georgia                282
# 8            Idaho                  2
# 9         Illinois                300
# 10         Indiana                159
# 11            Iowa                  5
# 12        Kentucky                 85
# 13       Louisiana                190
# 14           Maine                 86
# 15        Maryland                  2
# 16   Massachusetts                 13
# 17        Michigan                 41
# 18       Minnesota                241
# 19     Mississippi                 88
# 20        Missouri                 60
# 21         Montana                 24
# 22          Nevada                 34
# 23   New Hampshire                 57
# 24      New Mexico                 72
# 25        New York                 26
# 26  North Carolina                333
# 27    North Dakota                 23
# 28            Ohio                237
# 29    Pennsylvania                  5
# 30  South Carolina                245
# 31    South Dakota                 19
# 32       Tennessee                105
# 33           Texas                676
# 34         Vermont                  6
# 35        Virginia                 21
# 36      Washington                 27
# 37   West Virginia                 15
# 38       Wisconsin                 29
# 39         Wyoming                  2

# %%
#unique site_id per Business Unit

unique_sites_per_BU = (
    merged_data.groupby('BU_simplified_name')['site_id']
    .nunique()
    .reset_index(name='unique_site_count')
)

unique_sites_per_BU.head(10)
# Out:
#   BU_simplified_name  unique_site_count
# 0  COASTAL CAROLINAS                366
# 1            FLORIDA                417
# 2       GRAND CANYON                589
# 3        GREAT LAKES                416
# 4         GULF COAST                477
# 5          HEARTLAND                365
# 6            MIDWEST                397
# 7      NORTHERN TIER                391
# 8    ROCKY MOUNTAINS                316
# 9     SOUTH ATLANTIC                346

# %%
#data for Texas

state_texas_data = merged_data[merged_data['site_state_desc'] == 'Texas']
state_texas_data.head()
# Out:
#      site_id fiscal_week_end_date  item_sales  units_sold  avg_basket  \
# 235  2741432             9/3/2023      161.03        76.0       13.66
# 236  2741432            1/14/2024     2461.31      1092.0       12.51
# 237  2741432           10/29/2023       58.26        25.0       12.42
# 238  2741432            3/19/2023       71.84        36.0       12.46
# 239  2741432            2/18/2024      263.44       111.0       10.55
#
#      units_per_basket  unit_price  gross_package_cost  net_single_unit_cost  \
# 235              5.74        2.23               26.95                  1.25
# 236              4.52        2.26               33.51                  1.28
# 237              4.36        2.33               26.48                  1.25
# 238              5.60        2.05               31.96                  1.25
# 239              4.28        2.37               33.22                  1.28
#
#      net_package_cost  ...  Fresh_Food_Fast_Program_Indicator  site_number.1  \
# 235              30.1  ...                               True        2741432
# 236              30.7  ...                               True        2741432
# 237              30.1  ...                               True        2741432
# 238              30.1  ...                               True        2741432
# 239              30.8  ...                               True        2741432
#
#              division_desc  Region_ID                        region_desc  \
# 235  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 236  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 237  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 238  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 239  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
#
#      Market_ID site_country_id  site_state_desc  BU_simplified_name  \
# 235       2849              US            Texas               TEXAS
# 236       2849              US            Texas               TEXAS
# 237       2849              US            Texas               TEXAS
# 238       2849              US            Texas               TEXAS
# 239       2849              US            Texas               TEXAS
#
#      Eastern_Canada_Breakdown
# 235                     Other
# 236                     Other
# 237                     Other
# 238                     Other
# 239                     Other
#
# [5 rows x 32 columns]

# %%
#Business Unit in Texas state

state_unique_sites_per_BU = (
    state_texas_data.groupby('BU_simplified_name')['site_id']
    .nunique()
    .reset_index(name='unique_site_count')
)

state_unique_sites_per_BU.head(10)
# Out:
#   BU_simplified_name  unique_site_count
# 0    ROCKY MOUNTAINS                 68
# 1              TEXAS                608

# %%
# Create a bar chart of unique sites per BU
sns.barplot(x='BU_simplified_name', y='unique_site_count', data=state_unique_sites_per_BU)
plt.xlabel('Business Unit')
plt.ylabel('Number of Unique Sites')
plt.title('Business Unit in Texas state')
plt.show()

# %%
#data for Business_unit "Texas"

BU_TEXAS_data = merged_data[merged_data['BU_simplified_name'] == 'TEXAS']
BU_TEXAS_data.to_csv('BU_TEXAS_data.csv', index=False)
BU_TEXAS_data.head()
# Out:
#      site_id fiscal_week_end_date  item_sales  units_sold  avg_basket  \
# 235  2741432             9/3/2023      161.03        76.0       13.66
# 236  2741432            1/14/2024     2461.31      1092.0       12.51
# 237  2741432           10/29/2023       58.26        25.0       12.42
# 238  2741432            3/19/2023       71.84        36.0       12.46
# 239  2741432            2/18/2024      263.44       111.0       10.55
#
#      units_per_basket  unit_price  gross_package_cost  net_single_unit_cost  \
# 235              5.74        2.23               26.95                  1.25
# 236              4.52        2.26               33.51                  1.28
# 237              4.36        2.33               26.48                  1.25
# 238              5.60        2.05               31.96                  1.25
# 239              4.28        2.37               33.22                  1.28
#
#      net_package_cost  ...  Fresh_Food_Fast_Program_Indicator  site_number.1  \
# 235              30.1  ...                               True        2741432
# 236              30.7  ...                               True        2741432
# 237              30.1  ...                               True        2741432
# 238              30.1  ...                               True        2741432
# 239              30.8  ...                               True        2741432
#
#              division_desc  Region_ID                        region_desc  \
# 235  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 236  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 237  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 238  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 239  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
#
#      Market_ID site_country_id  site_state_desc  BU_simplified_name  \
# 235       2849              US            Texas               TEXAS
# 236       2849              US            Texas               TEXAS
# 237       2849              US            Texas               TEXAS
# 238       2849              US            Texas               TEXAS
# 239       2849              US            Texas               TEXAS
#
#      Eastern_Canada_Breakdown
# 235                     Other
# 236                     Other
# 237                     Other
# 238                     Other
# 239                     Other
#
# [5 rows x 32 columns]

# %%
print(BU_TEXAS_data.shape)
# Out:
# (13973, 32)

# %%
# check NaN values for each column

nan_values = BU_TEXAS_data.isnull().sum()

print(nan_values)
# Out:
# site_id                                 0
# fiscal_week_end_date                    0
# item_sales                              0
# units_sold                              0
# avg_basket                              0
# units_per_basket                        0
# unit_price                              0
# gross_package_cost                    316
# net_single_unit_cost                 5716
# net_package_cost                     5716
# num_transactions                        0
# store_size                              0
# market_share                            0
# car_traffic                            20
# seconds_to_near_highway                 0
# dist_nearest_act_site                   0
# Final_urbanicity                        0
# Pop_Estimate_CrYr                       0
# dist_nearest_grocery                   16
# Total_merch_revenue_2022                0
# Median_HH_Income_CrYr                   0
# closest_tier1_competitor               43
# Fresh_Food_Fast_Program_Indicator       0
# site_number.1                           0
# division_desc                           0
# Region_ID                               0
# region_desc                             0
# Market_ID                               0
# site_country_id                         0
# site_state_desc                         0
# BU_simplified_name                      0
# Eastern_Canada_Breakdown                0
# dtype: int64

# %%
# Count the number of data for each unique site_id
count_per_site_id = BU_TEXAS_data['site_id'].value_counts()

# Print the count for each site_id
print(count_per_site_id)
# Out:
# 2742101    37
# 2742417    33
# 2741095    33
# 2742166    33
# 2706340    32
#            ..
# 2743946    13
# 2741823    12
# 2742412    12
# 2741009     9
# 2742330     6
# Name: site_id, Length: 608, dtype: int64

# %%
# Remove rows where the count_per_site_id value is not 55

#BU_TEXAS_data = BU_TEXAS_data[BU_TEXAS_data['site_id'].isin(count_per_site_id[count_per_site_id == 55].index)]

# %%
print(BU_TEXAS_data.shape)
# Out:
# (13973, 32)

# %%
# Number of unique site_id after removing site_id != 55

unique_site_id_count = BU_TEXAS_data['site_id'].nunique()

print(unique_site_id_count)
# Out:
# 608

# %%
# prompt: create a csv file BU_TEXAS_data

BU_TEXAS_data.to_csv('BU_TEXAS_data.csv', index=False)

# %%
BU_TEXAS_data.head()
# Out:
#      site_id fiscal_week_end_date  item_sales  units_sold  avg_basket  \
# 235  2741432             9/3/2023      161.03        76.0       13.66
# 236  2741432            1/14/2024     2461.31      1092.0       12.51
# 237  2741432           10/29/2023       58.26        25.0       12.42
# 238  2741432            3/19/2023       71.84        36.0       12.46
# 239  2741432            2/18/2024      263.44       111.0       10.55
#
#      units_per_basket  unit_price  gross_package_cost  net_single_unit_cost  \
# 235              5.74        2.23               26.95                  1.25
# 236              4.52        2.26               33.51                  1.28
# 237              4.36        2.33               26.48                  1.25
# 238              5.60        2.05               31.96                  1.25
# 239              4.28        2.37               33.22                  1.28
#
#      net_package_cost  ...  Fresh_Food_Fast_Program_Indicator  site_number.1  \
# 235              30.1  ...                               True        2741432
# 236              30.7  ...                               True        2741432
# 237              30.1  ...                               True        2741432
# 238              30.1  ...                               True        2741432
# 239              30.8  ...                               True        2741432
#
#              division_desc  Region_ID                        region_desc  \
# 235  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 236  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 237  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 238  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
# 239  2800 - Texas Division       2840  2840 - TX Region - Tonjalia Green
#
#      Market_ID site_country_id  site_state_desc  BU_simplified_name  \
# 235       2849              US            Texas               TEXAS
# 236       2849              US            Texas               TEXAS
# 237       2849              US            Texas               TEXAS
# 238       2849              US            Texas               TEXAS
# 239       2849              US            Texas               TEXAS
#
#      Eastern_Canada_Breakdown
# 235                     Other
# 236                     Other
# 237                     Other
# 238                     Other
# 239                     Other
#
# [5 rows x 32 columns]

# %%
# Create column fiscal_week_end_date as a time frame

BU_TEXAS_data['fiscal_week_end_date'] = pd.to_datetime(BU_TEXAS_data['fiscal_week_end_date'])
BU_TEXAS_data.head()
# Out:
# <ipython-input-47-1b4daa7688d9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BU_TEXAS_data['fiscal_week_end_date'] = pd.to_datetime(BU_TEXAS_data['fiscal_week_end_date'])
#        site_id fiscal_week_end_date  item_sales  units_sold  avg_basket  \
# 89687  2741073           2023-02-05       19.92         8.0       11.09
# 44672  2741905           2023-02-05       26.41        11.0       30.65
# 55974  2742428           2023-02-05        4.98         2.0       11.87
# 75173  2742345           2023-02-05        8.98         5.0       13.31
# 81586  2741827           2023-02-05       19.10         8.0       16.37
#
#        units_per_basket  unit_price  gross_package_cost  net_single_unit_cost  \
# 89687              5.21        2.49               30.28                  1.25
# 44672             11.41        2.40               30.36                  1.25
# 55974              3.50        2.49                 NaN                   NaN
# 75173              4.33        1.89               31.20                  1.25
# 81586              5.31        2.39               32.25                   NaN
#
#        net_package_cost  ...  site_number.1          division_desc  Region_ID  \
# 89687              30.1  ...        2741073  2800 - Texas Division       2880
# 44672              30.1  ...        2741905  2800 - Texas Division       2830
# 55974               NaN  ...        2742428  2800 - Texas Division       2870
# 75173              30.1  ...        2742345  2800 - Texas Division       2830
# 81586               NaN  ...        2741827  2800 - Texas Division       2860
#
#                                region_desc  Market_ID  site_country_id  \
# 89687   2880 - TX Region - Michael Stowers       2884               US
# 44672  2830 - TX Region - Charles  Braxton       2837               US
# 55974        2870 - TX Region - Ben Wilson       2873               US
# 75173  2830 - TX Region - Charles  Braxton       2833               US
# 81586     2860 - TX Region - Gary Skillern       2866               US
#
#       site_state_desc  BU_simplified_name  Eastern_Canada_Breakdown  profit
# 89687           Texas               TEXAS                     Other    9.92
# 44672           Texas               TEXAS                     Other   12.65
# 55974           Texas               TEXAS                     Other     NaN
# 75173           Texas               TEXAS                     Other    3.20
# 81586           Texas               TEXAS                     Other     NaN
#
# [5 rows x 33 columns]

# %%
# Sort Value

BU_TEXAS_data.sort_values(by='fiscal_week_end_date', inplace=True)
# Out:
# <ipython-input-20-eddb0619e7d5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BU_TEXAS_data.sort_values(by='fiscal_week_end_date', inplace=True)

# %%
# aggregate item_sales weekly

weekly_sales = BU_TEXAS_data.groupby('fiscal_week_end_date')['item_sales'].sum()
print(weekly_sales)
# Out:
# fiscal_week_end_date
# 2023-02-05      6593.51
# 2023-02-12      9526.54
# 2023-02-19     12207.34
# 2023-02-26     13781.37
# 2023-03-05     11849.27
# 2023-03-12     11668.26
# 2023-03-19     10853.86
# 2023-03-26      9210.78
# 2023-04-02     10400.36
# 2023-04-09      8658.91
# 2023-04-16     10314.47
# 2023-04-23     12418.15
# 2023-04-30     12487.62
# 2023-05-07     15671.09
# 2023-05-14     15774.22
# 2023-05-21     18999.69
# 2023-05-28     21739.52
# 2023-06-04     22734.67
# 2023-06-11     20085.76
# 2023-06-18     22017.52
# 2023-06-25     22530.12
# 2023-07-02     20994.48
# 2023-07-09     17094.16
# 2023-07-16     18660.54
# 2023-07-23     18046.27
# 2023-07-30     16569.76
# 2023-08-06     14981.80
# 2023-08-13     14816.44
# 2023-08-20     12194.56
# 2023-08-27      9428.45
# 2023-09-03      9743.74
# 2023-09-10     10509.01
# 2023-09-17     12315.05
# 2023-09-24     13228.41
# 2023-10-01     14594.81
# 2023-10-08     13077.16
# 2023-10-15     13943.64
# 2023-10-22     13804.91
# 2023-10-29     12088.43
# 2023-11-05     11354.79
# 2023-11-12     10744.22
# 2023-11-19     10288.38
# 2023-11-26    475264.15
# 2023-12-03    602510.81
# 2023-12-10    641936.01
# 2023-12-17    683459.31
# 2023-12-24    724532.97
# 2023-12-31    717116.04
# 2024-01-07    555226.90
# 2024-01-14    647236.71
# 2024-01-21    576767.28
# 2024-01-28    649640.44
# 2024-02-04    678733.29
# 2024-02-11    710014.34
# 2024-02-18     86869.65
# Name: item_sales, dtype: float64

# %%
#Create a line graph for weekly_sales

weekly_sales.plot(kind='line', figsize=(10, 6))
plt.xlabel('Fiscal Week End Date')
plt.ylabel('Total Item Sales')
plt.title('Weekly Item Sales for BU_TEXAS')
plt.show()

# %%
# show data with site_id = 2722003

BU_TEXAS_data[BU_TEXAS_data['site_id'] == 2742101]
# Out:
#        site_id fiscal_week_end_date  item_sales  units_sold  avg_basket  \
# 33686  2742101           2023-02-12       84.74        38.0       13.39
# 33714  2742101           2023-02-26       84.90        37.0       15.29
# 33696  2742101           2023-03-05       87.72        38.0       19.27
# 33698  2742101           2023-03-12       68.25        30.0       11.36
# 33711  2742101           2023-03-26       80.29        35.0       15.66
# 33687  2742101           2023-04-02       69.27        31.0       15.07
# 33697  2742101           2023-04-16       80.29        35.0       16.11
# 33710  2742101           2023-04-23       84.25        36.0       17.32
# 33694  2742101           2023-04-30       54.82        23.0       20.37
# 33720  2742101           2023-05-07      107.15        45.0       12.94
# 33695  2742101           2023-05-21       77.76        37.0       14.30
# 33703  2742101           2023-06-04      104.70        47.0       10.43
# 33712  2742101           2023-06-18      241.71       101.0       12.12
# 33685  2742101           2023-06-25      160.51        68.0       12.89
# 33693  2742101           2023-07-16      170.09        73.0       12.98
# 33705  2742101           2023-07-23       53.47        22.0       18.42
# 33716  2742101           2023-08-06      108.20        46.0       10.99
# 33700  2742101           2023-08-20       80.88        35.0       12.04
# 33692  2742101           2023-08-27      114.17        49.0       12.21
# 33691  2742101           2023-09-10      124.56        51.0       15.85
# 33702  2742101           2023-09-17       95.56        40.0       18.79
# 33717  2742101           2023-09-24       82.35        33.0       13.61
# 33708  2742101           2023-10-01      151.32        60.0       13.85
# 33706  2742101           2023-10-15      101.96        40.0       18.19
# 33701  2742101           2023-10-22       74.73        30.0       12.33
# 33699  2742101           2023-11-05       95.31        39.0       14.13
# 33718  2742101           2023-11-12       69.21        28.0       14.26
# 33704  2742101           2023-11-19       48.19        21.0       12.03
# 33715  2742101           2023-12-10     4332.90      1941.0       14.52
# 33690  2742101           2023-12-17     3898.24      1735.0       13.83
# 33707  2742101           2023-12-24     3870.62      1736.0       13.60
# 33709  2742101           2023-12-31     4074.74      1837.0       15.43
# 33719  2742101           2024-01-14     3913.73      1700.0       16.29
# 33688  2742101           2024-01-21     3217.43      1394.0       14.15
# 33721  2742101           2024-01-28     3250.33      1359.0       14.55
# 33713  2742101           2024-02-04     4240.29      1760.0       13.19
# 33689  2742101           2024-02-18      399.28       165.0       14.77
#
#        units_per_basket  unit_price  gross_package_cost  net_single_unit_cost  \
# 33686              5.24        2.23               31.24                  1.25
# 33714              4.80        2.29               31.25                  1.25
# 33696              7.31        2.32               30.62                  1.25
# 33698              4.82        2.28               31.07                  1.25
# 33711              6.31        2.29               31.49                  1.25
# 33687              5.55        2.23               31.99                  1.25
# 33697              6.64        2.29               31.49                  1.25
# 33710              5.30        2.36               31.32                  1.25
# 33694              8.74        2.39               31.42                  1.25
# 33720              4.50        2.38               31.68                  1.25
# 33695              5.17        2.10               31.64                  1.25
# 33703              4.28        2.23               31.87                  1.25
# 33712              4.72        2.40               32.06                  1.25
# 33685              4.69        2.36               31.98                  1.25
# 33693              5.30        2.34               27.43                  1.25
# 33705              6.65        2.43               29.31                  1.25
# 33716              4.50        2.35               29.89                  1.25
# 33700              4.72        2.35               29.32                  1.25
# 33692              4.49        2.33               28.01                  1.25
# 33691              5.00        2.44               28.09                  1.25
# 33702              7.20        2.39               28.33                  1.25
# 33717              4.67        2.50               30.88                  1.25
# 33708              4.87        2.52               29.57                  1.25
# 33706              6.68        2.55               27.12                  1.25
# 33701              4.10        2.49               26.48                  1.25
# 33699              4.55        2.44               30.85                  1.25
# 33718              4.58        2.47               27.76                  1.25
# 33704              4.33        2.29               29.46                  1.25
# 33715              5.43        2.24               33.05                  1.28
# 33690              5.44        2.25               33.03                  1.28
# 33707              5.00        2.24               33.08                  1.28
# 33709              5.28        2.22               33.06                  1.28
# 33719              5.43        2.31               33.60                  1.28
# 33688              5.17        2.31               33.55                  1.28
# 33721              5.22        2.40               33.45                  1.28
# 33713              4.76        2.42               33.50                  1.28
# 33689              4.64        2.42               33.78                  1.28
#
#        net_package_cost  ...  Fresh_Food_Fast_Program_Indicator  \
# 33686             30.10  ...                               True
# 33714             30.10  ...                               True
# 33696             30.10  ...                               True
# 33698             30.10  ...                               True
# 33711             30.10  ...                               True
# 33687             30.10  ...                               True
# 33697             30.10  ...                               True
# 33710             30.10  ...                               True
# 33694             30.10  ...                               True
# 33720             30.10  ...                               True
# 33695             30.10  ...                               True
# 33703             30.10  ...                               True
# 33712             30.10  ...                               True
# 33685             30.10  ...                               True
# 33693             30.10  ...                               True
# 33705             30.10  ...                               True
# 33716             30.10  ...                               True
# 33700             30.10  ...                               True
# 33692             30.10  ...                               True
# 33691             30.10  ...                               True
# 33702             30.10  ...                               True
# 33717             30.10  ...                               True
# 33708             30.10  ...                               True
# 33706             30.10  ...                               True
# 33701             30.10  ...                               True
# 33699             30.10  ...                               True
# 33718             30.10  ...                               True
# 33704             30.10  ...                               True
# 33715             30.75  ...                               True
# 33690             30.75  ...                               True
# 33707             30.75  ...                               True
# 33709             30.73  ...                               True
# 33719             30.74  ...                               True
# 33688             30.73  ...                               True
# 33721             30.70  ...                               True
# 33713             30.73  ...                               True
# 33689             30.79  ...                               True
#
#        site_number.1          division_desc  Region_ID  \
# 33686        2742101  2800 - Texas Division       2840
# 33714        2742101  2800 - Texas Division       2840
# 33696        2742101  2800 - Texas Division       2840
# 33698        2742101  2800 - Texas Division       2840
# 33711        2742101  2800 - Texas Division       2840
# 33687        2742101  2800 - Texas Division       2840
# 33697        2742101  2800 - Texas Division       2840
# 33710        2742101  2800 - Texas Division       2840
# 33694        2742101  2800 - Texas Division       2840
# 33720        2742101  2800 - Texas Division       2840
# 33695        2742101  2800 - Texas Division       2840
# 33703        2742101  2800 - Texas Division       2840
# 33712        2742101  2800 - Texas Division       2840
# 33685        2742101  2800 - Texas Division       2840
# 33693        2742101  2800 - Texas Division       2840
# 33705        2742101  2800 - Texas Division       2840
# 33716        2742101  2800 - Texas Division       2840
# 33700        2742101  2800 - Texas Division       2840
# 33692        2742101  2800 - Texas Division       2840
# 33691        2742101  2800 - Texas Division       2840
# 33702        2742101  2800 - Texas Division       2840
# 33717        2742101  2800 - Texas Division       2840
# 33708        2742101  2800 - Texas Division       2840
# 33706        2742101  2800 - Texas Division       2840
# 33701        2742101  2800 - Texas Division       2840
# 33699        2742101  2800 - Texas Division       2840
# 33718        2742101  2800 - Texas Division       2840
# 33704        2742101  2800 - Texas Division       2840
# 33715        2742101  2800 - Texas Division       2840
# 33690        2742101  2800 - Texas Division       2840
# 33707        2742101  2800 - Texas Division       2840
# 33709        2742101  2800 - Texas Division       2840
# 33719        2742101  2800 - Texas Division       2840
# 33688        2742101  2800 - Texas Division       2840
# 33721        2742101  2800 - Texas Division       2840
# 33713        2742101  2800 - Texas Division       2840
# 33689        2742101  2800 - Texas Division       2840
#
#                              region_desc  Market_ID site_country_id  \
# 33686  2840 - TX Region - Tonjalia Green       2848              US
# 33714  2840 - TX Region - Tonjalia Green       2848              US
# 33696  2840 - TX Region - Tonjalia Green       2848              US
# 33698  2840 - TX Region - Tonjalia Green       2848              US
# 33711  2840 - TX Region - Tonjalia Green       2848              US
# 33687  2840 - TX Region - Tonjalia Green       2848              US
# 33697  2840 - TX Region - Tonjalia Green       2848              US
# 33710  2840 - TX Region - Tonjalia Green       2848              US
# 33694  2840 - TX Region - Tonjalia Green       2848              US
# 33720  2840 - TX Region - Tonjalia Green       2848              US
# 33695  2840 - TX Region - Tonjalia Green       2848              US
# 33703  2840 - TX Region - Tonjalia Green       2848              US
# 33712  2840 - TX Region - Tonjalia Green       2848              US
# 33685  2840 - TX Region - Tonjalia Green       2848              US
# 33693  2840 - TX Region - Tonjalia Green       2848              US
# 33705  2840 - TX Region - Tonjalia Green       2848              US
# 33716  2840 - TX Region - Tonjalia Green       2848              US
# 33700  2840 - TX Region - Tonjalia Green       2848              US
# 33692  2840 - TX Region - Tonjalia Green       2848              US
# 33691  2840 - TX Region - Tonjalia Green       2848              US
# 33702  2840 - TX Region - Tonjalia Green       2848              US
# 33717  2840 - TX Region - Tonjalia Green       2848              US
# 33708  2840 - TX Region - Tonjalia Green       2848              US
# 33706  2840 - TX Region - Tonjalia Green       2848              US
# 33701  2840 - TX Region - Tonjalia Green       2848              US
# 33699  2840 - TX Region - Tonjalia Green       2848              US
# 33718  2840 - TX Region - Tonjalia Green       2848              US
# 33704  2840 - TX Region - Tonjalia Green       2848              US
# 33715  2840 - TX Region - Tonjalia Green       2848              US
# 33690  2840 - TX Region - Tonjalia Green       2848              US
# 33707  2840 - TX Region - Tonjalia Green       2848              US
# 33709  2840 - TX Region - Tonjalia Green       2848              US
# 33719  2840 - TX Region - Tonjalia Green       2848              US
# 33688  2840 - TX Region - Tonjalia Green       2848              US
# 33721  2840 - TX Region - Tonjalia Green       2848              US
# 33713  2840 - TX Region - Tonjalia Green       2848              US
# 33689  2840 - TX Region - Tonjalia Green       2848              US
#
#        site_state_desc  BU_simplified_name  Eastern_Canada_Breakdown
# 33686            Texas               TEXAS                     Other
# 33714            Texas               TEXAS                     Other
# 33696            Texas               TEXAS                     Other
# 33698            Texas               TEXAS                     Other
# 33711            Texas               TEXAS                     Other
# 33687            Texas               TEXAS                     Other
# 33697            Texas               TEXAS                     Other
# 33710            Texas               TEXAS                     Other
# 33694            Texas               TEXAS                     Other
# 33720            Texas               TEXAS                     Other
# 33695            Texas               TEXAS                     Other
# 33703            Texas               TEXAS                     Other
# 33712            Texas               TEXAS                     Other
# 33685            Texas               TEXAS                     Other
# 33693            Texas               TEXAS                     Other
# 33705            Texas               TEXAS                     Other
# 33716            Texas               TEXAS                     Other
# 33700            Texas               TEXAS                     Other
# 33692            Texas               TEXAS                     Other
# 33691            Texas               TEXAS                     Other
# 33702            Texas               TEXAS                     Other
# 33717            Texas               TEXAS                     Other
# 33708            Texas               TEXAS                     Other
# 33706            Texas               TEXAS                     Other
# 33701            Texas               TEXAS                     Other
# 33699            Texas               TEXAS                     Other
# 33718            Texas               TEXAS                     Other
# 33704            Texas               TEXAS                     Other
# 33715            Texas               TEXAS                     Other
# 33690            Texas               TEXAS                     Other
# 33707            Texas               TEXAS                     Other
# 33709            Texas               TEXAS                     Other
# 33719            Texas               TEXAS                     Other
# 33688            Texas               TEXAS                     Other
# 33721            Texas               TEXAS                     Other
# 33713            Texas               TEXAS                     Other
# 33689            Texas               TEXAS                     Other
#
# [37 rows x 32 columns]

# %%
plt.hist(BU_TEXAS_data['unit_price'])
# Out:
# (array([4.000e+00, 5.000e+00, 9.000e+00, 2.200e+01, 7.900e+01, 1.990e+02,
#         9.410e+02, 9.058e+03, 3.655e+03, 1.000e+00]),
#  array([0.   , 0.302, 0.604, 0.906, 1.208, 1.51 , 1.812, 2.114, 2.416,
#         2.718, 3.02 ]),
#  <BarContainer object of 10 artists>)

# %%
BU_TEXAS_data[['unit_price', 'units_sold', 'avg_basket']].describe()
# Out:
#          unit_price    units_sold    avg_basket
# count  13973.000000  13973.000000  13973.000000
# mean       2.304074    265.235239     13.385884
# std        0.192659    514.376445      4.964645
# min        0.000000      0.000000    -20.900000
# 25%        2.230000     14.000000     10.880000
# 50%        2.330000     27.000000     12.920000
# 75%        2.420000     78.000000     15.030000
# max        3.020000   3869.000000    172.520000

# %%
BU_TEXAS_data.columns
# Out:
# Index(['site_id', 'fiscal_week_end_date', 'item_sales', 'units_sold',
#        'avg_basket', 'units_per_basket', 'unit_price', 'gross_package_cost',
#        'net_single_unit_cost', 'net_package_cost', 'num_transactions',
#        'store_size', 'market_share', 'car_traffic', 'seconds_to_near_highway',
#        'dist_nearest_act_site', 'Final_urbanicity', 'Pop_Estimate_CrYr',
#        'dist_nearest_grocery', 'Total_merch_revenue_2022',
#        'Median_HH_Income_CrYr', 'closest_tier1_competitor',
#        'Fresh_Food_Fast_Program_Indicator', 'site_number.1', 'division_desc',
#        'Region_ID', 'region_desc', 'Market_ID', 'site_country_id',
#        'site_state_desc', 'BU_simplified_name', 'Eastern_Canada_Breakdown'],
#       dtype='object')

# %%
BU_TEXAS_data.iloc[0,]
# Out:
# site_id                                                         2741073
# fiscal_week_end_date                                2023-02-05 00:00:00
# item_sales                                                        19.92
# units_sold                                                          8.0
# avg_basket                                                        11.09
# units_per_basket                                                   5.21
# unit_price                                                         2.49
# gross_package_cost                                                30.28
# net_single_unit_cost                                               1.25
# net_package_cost                                                   30.1
# num_transactions                                                    7.0
# store_size                                                         3627
# market_share                                                   0.086957
# car_traffic                                                    224954.0
# seconds_to_near_highway                                             316
# dist_nearest_act_site                                          0.728986
# Final_urbanicity                                               Suburban
# Pop_Estimate_CrYr                                          31427.577474
# dist_nearest_grocery                                           0.384442
# Total_merch_revenue_2022                                    2629548.834
# Median_HH_Income_CrYr                                      57039.256654
# closest_tier1_competitor                                       0.222433
# Fresh_Food_Fast_Program_Indicator                                  True
# site_number.1                                                   2741073
# division_desc                                     2800 - Texas Division
# Region_ID                                                          2880
# region_desc                          2880 - TX Region - Michael Stowers
# Market_ID                                                          2884
# site_country_id                                                      US
# site_state_desc                                                   Texas
# BU_simplified_name                                                TEXAS
# Eastern_Canada_Breakdown                                          Other
# profit                                                             9.92
# Name: 89687, dtype: object

# %%
BU_TEXAS_data['profit'] = BU_TEXAS_data['units_sold']*(BU_TEXAS_data['unit_price'] - BU_TEXAS_data['net_single_unit_cost'])
# Out:
# <ipython-input-39-51e48857a520>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BU_TEXAS_data['profit'] = BU_TEXAS_data['units_sold']*(BU_TEXAS_data['unit_price'] - BU_TEXAS_data['net_single_unit_cost'])

# %%
BU_TEXAS_data[['unit_price', 'net_single_unit_cost', 'units_sold', 'avg_basket', 'profit']].describe()
# Out:
#          unit_price  net_single_unit_cost    units_sold    avg_basket  \
# count  13973.000000           8257.000000  13973.000000  13973.000000
# mean       2.304074              1.268971    265.235239     13.385884
# std        0.192659              0.023777    514.376445      4.964645
# min        0.000000              1.250000      0.000000    -20.900000
# 25%        2.230000              1.250000     14.000000     10.880000
# 50%        2.330000              1.250000     27.000000     12.920000
# 75%        2.420000              1.280000     78.000000     15.030000
# max        3.020000              1.340000   3869.000000    172.520000
#
#             profit
# count  8257.000000
# mean    430.281721
# std     609.027180
# min      -9.500000
# 25%      21.750000
# 50%      48.960000
# 75%     787.080000
# max    4217.210000

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['units_sold'])
plt.xlim(2,2.75)
# Out:
# (2.0, 2.75)

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['units_sold'])

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['units_sold'])
plt.xlim(2,2.75)
# Out:
# (2.0, 2.75)

# %%
BU_TEXAS_data.loc['unit_price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'unit_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-96b97b018e83> in <cell line: 1>()
# ----> 1 BU_TEXAS_data.loc['unit_price']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1258     def _get_label(self, label, axis: int):
#    1259         # GH#5567 this will fail if the label is not present in the axis.
# -> 1260         return self.obj.xs(label, axis=axis)
#    1261
#    1262     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4054                     new_index = index[loc]
#    4055         else:
# -> 4056             loc = index.get_loc(key)
#    4057
#    4058             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'unit_price'
