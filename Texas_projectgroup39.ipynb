# %% [markdown]
# <a href="https://colab.research.google.com/github/MariamAmmar/6644_Final_Project/blob/main/Texas_projectgroup39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url1 = '/content/sample_data/price_fact.csv'
price_data = pd.read_csv(url1)
url2 = '/content/sample_data/site_dim.csv'
site_data = pd.read_csv(url2)

# %%
#rename column site_number to site_id

site_data.rename(columns={'site_number': 'site_id'}, inplace=True)

# %%
#Merge price_data and site_data based on site_number column

merged_data = pd.merge(price_data, site_data, on='site_id')

# %%
unique_sites_per_state = (
    merged_data.groupby('site_state_desc')['site_id']
    .nunique()
    .reset_index(name='unique_site_count')
)

print(unique_sites_per_state)
# Out:
#    site_state_desc  unique_site_count
# 0          Alabama                145
# 1           Alaska                 24
# 2          Arizona                555
# 3         Arkansas                 12
# 4       California                165
# 5         Colorado                176
# 6          Florida                638
# 7          Georgia                282
# 8            Idaho                  2
# 9         Illinois                300
# 10         Indiana                159
# 11            Iowa                  5
# 12        Kentucky                 85
# 13       Louisiana                190
# 14           Maine                 86
# 15        Maryland                  2
# 16   Massachusetts                 13
# 17        Michigan                 41
# 18       Minnesota                241
# 19     Mississippi                 88
# 20        Missouri                 60
# 21         Montana                 24
# 22          Nevada                 34
# 23   New Hampshire                 57
# ...

# %%
#unique site_id per Business Unit

unique_sites_per_BU = (
    merged_data.groupby('BU_simplified_name')['site_id']
    .nunique()
    .reset_index(name='unique_site_count')
)

unique_sites_per_BU.head(10)
# Out:
#   BU_simplified_name  unique_site_count
# 0  COASTAL CAROLINAS                366
# 1            FLORIDA                417
# 2       GRAND CANYON                589
# 3        GREAT LAKES                416
# 4         GULF COAST                477
# 5          HEARTLAND                365
# 6            MIDWEST                397
# 7      NORTHERN TIER                391
# 8    ROCKY MOUNTAINS                316
# 9     SOUTH ATLANTIC                346

# %%
#data for Texas
merged_data = pd.read_csv('/content/sample_data/master_data.csv')
state_texas_data = merged_data[merged_data['site_state_desc'] == 'Texas']
state_texas_data.head()
# Out:
# <ipython-input-3-d82cf0a0af12>:2: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_data = pd.read_csv('/content/sample_data/master_data.csv')
#      site_number fiscal_week_end_date  item_sales  units_sold  unit_price  \
# 438      2740079            3/26/2023     1222.37         488        2.50
# 439      2740079            4/16/2023     1396.52         514        2.72
# 440      2740079            10/1/2023     1506.21         616        2.45
# 441      2740079            3/10/2024     1348.45         511        2.64
# 442      2740079             4/2/2023     1406.98         526        2.67
#
#      gross_margin  margin_rate  net_single_unit_margin  net_single_unit_cost  \
# 438        498.43         0.41                    1.02                  1.48
# 439        535.77         0.38                    1.04                  1.67
# 440        530.13         0.35                    0.86                  1.58
# ...

# %%
#Business Unit in Texas state

state_unique_sites_per_BU = (
    state_texas_data.groupby('BU_simplified_name')['site_number']
    .nunique()
    .reset_index(name='unique_site_count')
)

state_unique_sites_per_BU.head(10)
# Out:
#   BU_simplified_name  unique_site_count
# 0    ROCKY MOUNTAINS                 22
# 1              TEXAS                173

# %%
# Create a bar chart of unique sites per BU
sns.barplot(x='BU_simplified_name', y='unique_site_count', data=state_unique_sites_per_BU)
plt.xlabel('Business Unit')
plt.ylabel('Number of Unique Sites')
plt.title('Business Unit in Texas state')
plt.show()

# %%
#data for Business_unit "Texas"

BU_TEXAS_data = merged_data[merged_data['BU_simplified_name'] == 'TEXAS']
BU_TEXAS_data.to_csv('BU_TEXAS_data.csv', index=False)
BU_TEXAS_data.head()
# Out:
#      site_number fiscal_week_end_date  item_sales  units_sold  unit_price  \
# 438      2740079            3/26/2023     1222.37         488        2.50
# 439      2740079            4/16/2023     1396.52         514        2.72
# 440      2740079            10/1/2023     1506.21         616        2.45
# 441      2740079            3/10/2024     1348.45         511        2.64
# 442      2740079             4/2/2023     1406.98         526        2.67
#
#      gross_margin  margin_rate  net_single_unit_margin  net_single_unit_cost  \
# 438        498.43         0.41                    1.02                  1.48
# 439        535.77         0.38                    1.04                  1.67
# 440        530.13         0.35                    0.86                  1.58
# 441        490.35         0.36                    0.96                  1.68
# 442        548.38         0.39                    1.04                  1.63
#
# ...

# %%
print(BU_TEXAS_data.shape)
# Out:
# (8798, 29)

# %%
# check NaN values for each column

nan_values = BU_TEXAS_data.isnull().sum()

print(nan_values)
# Out:
# site_number                    0
# fiscal_week_end_date           0
# item_sales                     0
# units_sold                     0
# unit_price                     0
# gross_margin                   0
# margin_rate                    0
# net_single_unit_margin         0
# net_single_unit_cost           0
# total_basket_sales             0
# total_basket_units             0
# num_transactions               0
# avg_basket                     0
# units_per_basket               0
# store_size                     0
# market_share                   0
# car_traffic                    0
# seconds_to_near_highway        0
# dist_nearest_act_site          0
# Final_urbanicity               0
# Pop_Estimate_CrYr              0
# dist_nearest_grocery           0
# Total_merch_revenue_2022       0
# Median_HH_Income_CrYr          0
# closest_tier1_competitor       0
# Region_ID                      0
# site_state_desc                0
# BU_simplified_name             0
# ...

# %%
# Count the number of data for each unique site_id
count_per_site_id = BU_TEXAS_data['site_number'].value_counts()

# Print the count for each site_id
print(count_per_site_id)
# Out:
# 2740079    51
# 2706984    51
# 2741338    51
# 2740527    51
# 2741319    51
#            ..
# 2741378    51
# 2741910    51
# 2741095    50
# 2742323    42
# 2742233    36
# Name: site_number, Length: 173, dtype: int64

# %%
# Remove rows where the count_per_site_id value is not 55

#BU_TEXAS_data = BU_TEXAS_data[BU_TEXAS_data['site_id'].isin(count_per_site_id[count_per_site_id == 55].index)]

# %%
print(BU_TEXAS_data.shape)
# Out:
# (8798, 29)

# %%
# Number of unique site_id after removing site_id != 55

unique_site_id_count = BU_TEXAS_data['site_number'].nunique()

print(unique_site_id_count)
# Out:
# 173

# %%
# prompt: create a csv file BU_TEXAS_data

BU_TEXAS_data.to_csv('BU_TEXAS_data.csv', index=False)

# %%
BU_TEXAS_data.head()
# Out:
#      site_id fiscal_week_end_date  item_sales  units_sold  avg_basket  \
# 235  2741432             9/3/2023      161.03        76.0       13.66
# 236  2741432            1/14/2024     2461.31      1092.0       12.51
# 237  2741432           10/29/2023       58.26        25.0       12.42
# 238  2741432            3/19/2023       71.84        36.0       12.46
# 239  2741432            2/18/2024      263.44       111.0       10.55
#
#      units_per_basket  unit_price  gross_package_cost  net_single_unit_cost  \
# 235              5.74        2.23               26.95                  1.25
# 236              4.52        2.26               33.51                  1.28
# 237              4.36        2.33               26.48                  1.25
# 238              5.60        2.05               31.96                  1.25
# 239              4.28        2.37               33.22                  1.28
#
#      net_package_cost  ...  Fresh_Food_Fast_Program_Indicator  site_number.1  \
# ...

# %%
# Create column fiscal_week_end_date as a time frame

BU_TEXAS_data['fiscal_week_end_date'] = pd.to_datetime(BU_TEXAS_data['fiscal_week_end_date'])
BU_TEXAS_data.head()
# Out:
# <ipython-input-17-1b4daa7688d9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BU_TEXAS_data['fiscal_week_end_date'] = pd.to_datetime(BU_TEXAS_data['fiscal_week_end_date'])
#      site_number fiscal_week_end_date  item_sales  units_sold  unit_price  \
# 438      2740079           2023-03-26     1222.37         488        2.50
# 439      2740079           2023-04-16     1396.52         514        2.72
# 440      2740079           2023-10-01     1506.21         616        2.45
# 441      2740079           2024-03-10     1348.45         511        2.64
# 442      2740079           2023-04-02     1406.98         526        2.67
#
#      gross_margin  margin_rate  net_single_unit_margin  net_single_unit_cost  \
# ...

# %%
# Sort Value

BU_TEXAS_data.sort_values(by='fiscal_week_end_date', inplace=True)
# Out:
# <ipython-input-18-eddb0619e7d5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BU_TEXAS_data.sort_values(by='fiscal_week_end_date', inplace=True)

# %%
# aggregate item_sales weekly

weekly_sales = BU_TEXAS_data.groupby('fiscal_week_end_date')['item_sales'].sum()
print(weekly_sales)
# Out:
# fiscal_week_end_date
# 2023-03-26    305981.16
# 2023-04-02    309087.71
# 2023-04-09    296274.78
# 2023-04-16    302353.07
# 2023-04-23    295908.21
# 2023-04-30    301698.21
# 2023-05-07    314525.63
# 2023-05-14    285737.47
# 2023-05-21    307710.22
# 2023-05-28    324241.47
# 2023-06-04    311533.42
# 2023-06-11    313294.61
# 2023-06-18    315675.65
# 2023-06-25    305929.52
# 2023-07-02    310964.81
# 2023-07-09    299872.06
# 2023-07-16    317275.38
# 2023-07-23    320949.02
# 2023-07-30    322003.40
# 2023-08-06    326183.45
# 2023-08-13    315809.62
# 2023-08-20    312812.56
# 2023-08-27    302908.21
# 2023-09-03    313252.14
# 2023-09-10    302971.84
# 2023-09-17    296433.21
# 2023-09-24    316060.09
# 2023-10-01    322842.31
# 2023-10-08    299319.47
# 2023-10-15    295651.11
# 2023-10-22    304390.42
# 2023-10-29    293696.38
# 2023-11-05    281772.76
# 2023-11-12    268970.95
# 2023-11-19    270613.75
# 2023-11-26    276523.52
# 2023-12-03    258781.70
# ...

# %%
#Create a line graph for weekly_sales

weekly_sales.plot(kind='line', figsize=(10, 6))
plt.xlabel('Fiscal Week End Date')
plt.ylabel('Total Item Sales')
plt.title('Weekly Item Sales for BU_TEXAS')
plt.show()

# %%
# show data with site_id = 2740079

BU_TEXAS_data[BU_TEXAS_data['site_number'] == 2740079]
# Out:
#      site_number fiscal_week_end_date  item_sales  units_sold  unit_price  \
# 438      2740079           2023-03-26     1222.37         488        2.50
# 442      2740079           2023-04-02     1406.98         526        2.67
# 454      2740079           2023-04-09     1207.78         486        2.49
# 439      2740079           2023-04-16     1396.52         514        2.72
# 457      2740079           2023-04-23     1232.08         477        2.58
# 465      2740079           2023-04-30     1446.59         565        2.56
# 446      2740079           2023-05-07     1446.30         537        2.69
# 482      2740079           2023-05-14     1254.47         467        2.69
# 477      2740079           2023-05-21     1430.02         551        2.60
# 481      2740079           2023-05-28     1439.02         556        2.59
# 459      2740079           2023-06-04     1199.94         480        2.50
# 472      2740079           2023-06-11     1101.96         435        2.53
# ...

# %%
plt.hist(BU_TEXAS_data['unit_price'])
# Out:
# (array([3.590e+02, 6.749e+03, 1.667e+03, 2.200e+01, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([2.   , 2.379, 2.758, 3.137, 3.516, 3.895, 4.274, 4.653, 5.032,
#         5.411, 5.79 ]),
#  <BarContainer object of 10 artists>)

# %%
BU_TEXAS_data[['unit_price', 'units_sold', 'avg_basket', 'gross_margin']].describe()
# Out:
#         unit_price   units_sold   avg_basket  gross_margin
# count  8798.000000  8798.000000  8798.000000   8798.000000
# mean      2.623717   649.496931    12.783429    637.040756
# std       0.160806   292.471400     1.412321    300.945832
# min       2.000000     4.000000     2.590000      2.280000
# 25%       2.520000   455.000000    11.822009    433.587500
# 50%       2.610000   584.000000    12.742905    569.610000
# 75%       2.720000   779.000000    13.690949    766.947500
# max       5.790000  2264.000000    20.953343   2259.960000

# %%
BU_TEXAS_data.columns
# Out:
# Index(['site_id', 'fiscal_week_end_date', 'item_sales', 'units_sold',
#        'avg_basket', 'units_per_basket', 'unit_price', 'gross_package_cost',
#        'net_single_unit_cost', 'net_package_cost', 'num_transactions',
#        'store_size', 'market_share', 'car_traffic', 'seconds_to_near_highway',
#        'dist_nearest_act_site', 'Final_urbanicity', 'Pop_Estimate_CrYr',
#        'dist_nearest_grocery', 'Total_merch_revenue_2022',
#        'Median_HH_Income_CrYr', 'closest_tier1_competitor',
#        'Fresh_Food_Fast_Program_Indicator', 'site_number.1', 'division_desc',
#        'Region_ID', 'region_desc', 'Market_ID', 'site_country_id',
#        'site_state_desc', 'BU_simplified_name', 'Eastern_Canada_Breakdown'],
#       dtype='object')

# %%
BU_TEXAS_data.iloc[0,]
# Out:
# site_number                             2740079
# fiscal_week_end_date        2023-03-26 00:00:00
# item_sales                              1222.37
# units_sold                                  488
# unit_price                                  2.5
# gross_margin                             498.43
# margin_rate                                0.41
# net_single_unit_margin                     1.02
# net_single_unit_cost                       1.48
# total_basket_sales                      3273.07
# total_basket_units                  1246.741002
# num_transactions                          299.0
# avg_basket                            10.946722
# units_per_basket                           4.17
# store_size                               2200.0
# market_share                           0.070423
# car_traffic                            935119.0
# seconds_to_near_highway                   125.0
# dist_nearest_act_site                  1.082184
# Final_urbanicity                          Urban
# ...

# %%
BU_TEXAS_data['profit'] = BU_TEXAS_data['units_sold']*(BU_TEXAS_data['unit_price'] - BU_TEXAS_data['net_single_unit_cost'])
# Out:
# <ipython-input-39-51e48857a520>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BU_TEXAS_data['profit'] = BU_TEXAS_data['units_sold']*(BU_TEXAS_data['unit_price'] - BU_TEXAS_data['net_single_unit_cost'])

# %%
BU_TEXAS_data[['unit_price', 'net_single_unit_cost', 'units_sold', 'avg_basket', 'profit']].describe()
# Out:
#          unit_price  net_single_unit_cost    units_sold    avg_basket  \
# count  13973.000000           8257.000000  13973.000000  13973.000000
# mean       2.304074              1.268971    265.235239     13.385884
# std        0.192659              0.023777    514.376445      4.964645
# min        0.000000              1.250000      0.000000    -20.900000
# 25%        2.230000              1.250000     14.000000     10.880000
# 50%        2.330000              1.250000     27.000000     12.920000
# 75%        2.420000              1.280000     78.000000     15.030000
# max        3.020000              1.340000   3869.000000    172.520000
#
#             profit
# count  8257.000000
# mean    430.281721
# std     609.027180
# min      -9.500000
# 25%      21.750000
# 50%      48.960000
# 75%     787.080000
# max    4217.210000

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['units_sold'])
plt.xlim(2,2.75)
# Out:
# (2.0, 2.75)

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['units_sold'])

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['units_sold'])
plt.xlim(2,2.75)
# Out:
# (2.0, 2.75)

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['gross_margin'])

# %%
plt.scatter(BU_TEXAS_data['unit_price'], BU_TEXAS_data['avg_basket'])
